# %%
import pandas as pd
import pickle

# %%
ofertas_nuevas_tecnoempleo = pd.read_pickle("/Pickles/general_tecnoempleo_limpio.pkl")
ofertas_nuevas_manfred = pd.read_pickle("/Pickles/manfred_general_limpio_actualizacion.pkl")

# %%
def fusion_nuevas_extracciones_general(ofertas_nuevas_tecnoempleo, ofertas_nuevas_manfred):
    
    ofertas_nuevas_tecnoempleo = 
    ofertas_nuevas_tecnoempleo.rename(columns={"Título": "titulo", "Nombre de empresa": "empresa", 
                                               "Ciudad": "ciudad", "Salario_desde": "salario_desde", 
                                               "Salario_hasta": "salario_hasta", "Jornada": "jornada_tipo",
                                               "Teletrabajo": "teletrabajo", "Time Stamp": "timestamp", 
                                               "Fecha publicacion" : "fecha_publicacion", 
                                               "Imprescindible Residir" : "imprescindible_residir", 
                                               "Funciones" : "funciones", "Nivel Profesional" : "nivel_profesional", 
                                               "CVs inscritos en el proceso" : "cvs_inscritos", 
                                               "Otras Provincias" : "otras_provincias", "Número de puestos" : "vacantes", 
                                               "Personas a cargo" : "personas_a_cargo", "+ Países" : "otros_paises",
                                               "URL" : "url", "Experiencia" : "experiencia", 
                                               "Tipo contrato" : "contrato_tipo", "Formación Mínima" : "formacion_minima"})
    
    ofertas_nuevas_manfred = 
    ofertas_nuevas_manfred.rename(columns={"Presencial": "ciudad", "Salario_desde": "salario_desde", 
                                                                    "Salario_hasta": "salario_hasta", "Jornada": "jornada_tipo",
                                                                    "Teletrabajo": "teletrabajo", "fecha_extraccion" : "timestamp"})
       
    ofertas_nuevas_tecnoempleo.drop(columns = ["Incentivos", "Info Otros Países", "otros_paises"], inplace = True)
    
    ofertas_nuevas_fusion = pd.concat([ofertas_nuevas_tecnoempleo, ofertas_nuevas_manfred], axis=0, join='outer', ignore_index=True)
    
    orden_columnas_fusion = ["id","empresa","titulo","ciudad", "salario_desde",
                             "salario_hasta","variable", "vacaciones", "teletrabajo",
                             "jornada_tipo", "turno_continuo", "imprescindible_residir", 
                             "funciones", "contrato_tipo", "nivel_profesional", 
                             "formacion_minima", "personas_a_cargo", "experiencia", 
                             "vacantes", "cvs_inscritos", "oferta_activada", 
                             "fecha_publicacion", "timestamp", "url"]
    
    ofertas_nuevas_fusion = ofertas_nuevas_fusion[orden_columnas_fusion]
    
    ofertas_nuevas_fusion["teletrabajo"] =  
    ofertas_nuevas_fusion["teletrabajo"].apply(lambda x : "Remoto" if x == 100 or x == "Remoto" else 
                                                                                       "Presencial" if x == 0 or x == "Presencial" else
                                                                                       "Hibrido")
    
    ofertas_nuevas_fusion["jornada_tipo"] = ofertas_nuevas_fusion["jornada_tipo"].astype(str).str.title()
    
  
    ofertas_nuevas_fusion["fecha_publicacion"] = pd.to_datetime(ofertas_nuevas_fusion["fecha_publicacion"]).dt.strftime("%Y-%m-%d %H:%M:%S")
    ofertas_nuevas_fusion["timestamp"] = pd.to_datetime(ofertas_nuevas_fusion["timestamp"]).dt.strftime("%Y-%m-%d %H:%M:%S")
    
    ofertas_nuevas_fusion["oferta_activada"] = ofertas_nuevas_fusion["oferta_activada"].fillna(1).astype(int)
    
    ofertas_nuevas_fusion.to_pickle("/Pickles/ofertas_nuevas.pkl")

    return ofertas_nuevas_fusion

# %%
fusion_nuevas_extracciones_general(ofertas_nuevas_tecnoempleo, ofertas_nuevas_manfred)
# Out:
#               id            empresa  \
# 0    id_tec_3605          NPR Spain
# 1    id_tec_3606   Farmacias Trebol
# 2    id_tec_3607  reef technologies
# 3    id_tec_3608   SEDITEL INTEGRAL
# 4    id_tec_3609    Infinity Neural
# ..           ...                ...
# 678  id_man_1241             durcal
# 679  id_man_1242          doofinder
# 680  id_man_1243           nexthink
# 681  id_man_1244               daar
# 682  id_man_1245          dynatrace
#
#                                             titulo       ciudad  \
# 0      UrgenteTécnico Senior Aplicaciones BBDD SQL  100% remoto
# 1            UrgenteSenior Python Backend Engineer       Madrid
# 2    UrgenteTécnico Sistemas de Telecomunicaciones  100% remoto
# 3                 Analista Pro. COBOL CICS DB2 JCL       Murcia
# 4                           Programadores React.JS    Barcelona
# ..                                             ...          ...
# 678                         Node Backend Developer    BARCELONA
# 679                              Software Engineer       MADRID
# 680                               Product Engineer       MADRID
# 681                               Junior Developer          NaN
# 682                    JavaScript Senior Developer    BARCELONA
#
#      salario_desde  salario_hasta  variable vacaciones teletrabajo  \
# 0            33.00           36.0       NaN        NaN     Hibrido
# 1            87.36          124.8       NaN        NaN  Presencial
# 2            27.00           30.0       NaN        NaN  Presencial
# 3            21.00           30.0       NaN        NaN  Presencial
# 4            24.00           30.0       NaN        NaN  Presencial
# ..             ...            ...       ...        ...         ...
# 678          40.00           45.0       NaN         23     Hibrido
# 679          32.00           48.0       NaN         24     Hibrido
# 680          75.00           75.0       NaN        NaN     Hibrido
# 681          27.00           27.0       NaN         25      Remoto
# 682          60.00           70.0       NaN         24      Remoto
#
#                   jornada_tipo  ...  nivel_profesional    formacion_minima  \
# 0             Jornada Completa  ...           Empleado                 FP1
# 1                    Por Horas  ...       Especialista        Sin estudios
# 2             Jornada Completa  ...           Empleado  FP2/Grado Superior
# 3             Jornada Completa  ...           Empleado           Diplomado
# 4             Jornada Completa  ...           Empleado  FP2/Grado Superior
# ..                         ...  ...                ...                 ...
# 678           Jornada Completa  ...                NaN                 NaN
# 679  Jornada Completa Flexible  ...                NaN                 NaN
# 680  Jornada Completa Flexible  ...                NaN                 NaN
# 681  Jornada Completa Flexible  ...                NaN                 NaN
# 682           Jornada Completa  ...                NaN                 NaN
#
#     personas_a_cargo    experiencia vacantes cvs_inscritos oferta_activada  \
# 0                NaN         3 años      NaN            33               1
# 1                NaN  Más de 5 años      NaN            54               1
# 2                NaN         2 años      NaN            33               1
# 3                NaN       3-5 años        6             0               1
# 4                NaN         3 años        6            92               1
# ..               ...            ...      ...           ...             ...
# 678              NaN            NaN      NaN           NaN               1
# 679              NaN            NaN      NaN           NaN               1
# 680              NaN            NaN      NaN           NaN               1
# 681              NaN            NaN      NaN           NaN               0
# 682              NaN            NaN      NaN           NaN               0
#
#        fecha_publicacion            timestamp  \
# 0    2025-03-05 00:00:00  2025-03-06 02:41:20
# 1    2025-03-05 00:00:00  2025-03-06 02:41:21
# 2    2025-03-05 00:00:00  2025-03-06 02:41:21
# 3    2025-03-05 00:00:00  2025-03-06 02:41:22
# 4    2025-03-05 00:00:00  2025-03-06 02:41:22
# ..                   ...                  ...
# 678                  NaN  2025-03-06 02:37:21
# 679                  NaN  2025-03-06 02:37:21
# 680                  NaN  2025-03-06 02:37:21
# 681                  NaN  2025-03-06 02:37:21
# 682                  NaN  2025-03-06 02:37:21
#
#                                                    url
# 0    https://www.tecnoempleo.com/tecnico-senior-apl...
# 1    https://www.tecnoempleo.com/senior-python-back...
# 2    https://www.tecnoempleo.com/tecnico-sistemas-t...
# 3    https://www.tecnoempleo.com/analista-pro-cobol...
# 4    https://www.tecnoempleo.com/programadores-reac...
# ..                                                 ...
# 678  https://www.getmanfred.com/ofertas-empleo/6879...
# 679  https://www.getmanfred.com/ofertas-empleo/6845...
# 680  https://www.getmanfred.com/ofertas-empleo/6503...
# 681  https://www.getmanfred.com/ofertas-empleo/6883...
# 682  https://www.getmanfred.com/ofertas-empleo/337/...
#
# [683 rows x 24 columns]

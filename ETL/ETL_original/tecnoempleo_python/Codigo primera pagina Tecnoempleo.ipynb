# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime

# %%
# Primero vemos cómo acceder a los enlaces de la primera página:
url = "https://www.tecnoempleo.com/ofertas-trabajo/?pagina=1"  

response = requests.get(url)
if response.status_code != 200:
    print("Error al acceder a la página principal")
    exit()

soup = BeautifulSoup(response.text, "html.parser")

enlaces = soup.find_all("a", class_="font-weight-bold text-cyan-700")
urls = [enlace.get("href") for enlace in enlaces if enlace.get("href")]
print (urls)

# %%
# Después accedemos a la información dentro de los enlaces de cada página:

url = "https://www.tecnoempleo.com/ofertas-trabajo/?pagina=1"  

response = requests.get(url)
if response.status_code != 200:
    print("Error al acceder a la página principal")
    exit()

soup = BeautifulSoup(response.text, "html.parser")

enlaces = soup.find_all("a", class_="font-weight-bold text-cyan-700")
urls = [enlace.get("href") for enlace in enlaces if enlace.get("href")]

for link in urls:

    response_link = requests.get(link)
    if response_link.status_code != 200: #En caso de que la solicitud no se procese correctamente, pedimos que nos lo comunique y que continue. 
        print(f"Error al acceder a {link}")
        continue

    soup_link = BeautifulSoup(response_link.text, "html.parser")
    # Sacamos título, fecha, habilidades, nombre de la empresa y añadimos el timestamp para que se indique la fecha en la que se han solicitado los datos. 
    titulo = soup_link.find("h1").get_text(strip=True) if soup_link.find("h1") else "Sin título"
    fecha = soup_link.find("span", class_= "ml-4").get_text(strip=True) if soup_link.find("span", class_= "ml-4").get_text else "Sin fecha" 
    nombre_empresa = [x.text.strip() for x in soup_link.find("div", class_ = "col-12 col-md-12 col-lg-8").find("a")][1]
    nombre_empresas = soup.find_all("a", class_="text-primary link-muted")
    for empresa in nombre_empresas:
        print(f"Nombre de empresa", empresa.text.strip())
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S") 

    
    # Tecnologías. En el caso de tecnologías, limpiamos ya la información que sacamos para que nos muestre solola tecnología sin el texto que no es necesario: "Ofertas de Empleo de":
    div = soup_link.find("div", class_="pl--12 pr--12")
    tecnologias = [a["title"].replace("Ofertas de Empleo de ", "") for a in div.find_all("a") if div and a.has_attr("title")] 
    
    #Todos los datos principales
    todos_textos_enunciados = [span.get_text(strip=True) for span in soup_link.find_all("span", class_="d-inline-block px-2")]
    todos_textos = [span.get_text(strip=True) for span in soup_link.find_all("span", class_="float-end")]

    #Otros detalles de la oferta
    todos_detalles = soup_link.find_all("p", class_="m-0")
    todos_textos_detalles = [x.text.strip() for x in todos_detalles if len(x["class"]) == 1] 

    # Printeamos toda la información que hemos sacado:
    print(f"Título: {titulo}")
    print(f"Fecha: {fecha}")
    print(f"Habilidades: {habilidades}")
    print(f"Time Stamp: {timestamp}")
    print(f"Tecnologías: {tecnologias}")
    print(f"Todos los textos de los datos principales: {todos_textos}")
    print(f"Todos los textos de detales: {todos_textos_detalles}")
    print("-" * 40) # Printeamos varios caracteres para diferenciar mejor a nivel visual una oferta de otra.
# Out:
# Nombre empresa : Gstock Web App
# Título: UrgenteIntegration Specialist
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Analista Programador', 'Consultor', 'Programador']
# Time Stamp: 2025-02-19 10:38:27
# Tecnologías: ['php', 'mysql', 'git', 'symfony', 'api', 'etl', 'sql', 'java', 'python', 'docker']
# Todos los textos de los datos principales: ['100% En remoto', 'España', 'Analista Programador', 'Intensiva Mañana', '1 año', 'Indefinido', '21.000 €\xa0-\xa024.000 € Bruto/año', 'phpmysqlgitsymfony']
# Todos los textos de detales: ['Analista Programador\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tConsultor\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tProgramador', 'Imprescindible Residir: España', 'Idiomas: Español (Excelente)\t\t\t\t\t\t\t\t\t\t| \r\n\t\t\t\t\t\t\t\t\t\tInglés (Alto)', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tFP2/Grado Superior', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  80']
# ----------------------------------------
# Nombre empresa : DAC.digital
# Título: UrgenteIT System Administrator/Web Developer
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Administrador', 'Programador', 'Técnico de Sistemas']
# Time Stamp: 2025-02-19 10:38:28
# Tecnologías: ['git', 'kubernetes', 'docker', 'agile', 'data', 'ci/cd', 'scrum', 'typo3']
# Todos los textos de los datos principales: ['100% En remoto', 'Not Required', 'Administrador', 'Jornada completa', '3-5 años', 'Freelance/Autónomo', '2.700 €\xa0-\xa06.000 € Bruto/mes', 'gitkubernetesdockeragile']
# Todos los textos de detales: ['Administrador\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tProgramador\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tTécnico de Sistemas', 'Imprescindible Residir: Not Required', 'Idiomas: Alemán (Alto)\t\t\t\t\t\t\t\t\t\t| \r\n\t\t\t\t\t\t\t\t\t\tInglés (Alto)', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tSin estudios', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEspecialista', 'CVs inscritos en el proceso:  102']
# ----------------------------------------
# Nombre empresa : Tecnonalia Network
# Título: UrgenteGestor de Proyectos .Net
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Jefe de Equipo', 'Jefe de Proyecto']
# Time Stamp: 2025-02-19 10:38:28
# Tecnologías: ['.net', 'sql', 'git', 'jira']
# Todos los textos de los datos principales: ['Madrid- España', 'Jefe de Equipo', 'Jornada completa', 'Más de 5 años', 'Indefinido', '42.000 €\xa0-\xa048.000 € Bruto/año', '.netsqlgitjira']
# Todos los textos de detales: ['Jefe de Equipo\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tJefe de Proyecto', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tDiplomado', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'Incentivos: Si. Bonus.', 'CVs inscritos en el proceso:  47']
# ----------------------------------------
# Nombre empresa : Iron Mountain
# Título: UrgenteAccount Executive with German
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Comercial', 'Consultor']
# Time Stamp: 2025-02-19 10:38:29
# Tecnologías: ['salesforce']
# Todos los textos de los datos principales: ['Llinars del Vallès -Barcelona(Híbrido)', 'País Puesto', 'Comercial', 'Jornada completa', '1 año', 'Indefinido', '39.000 €\xa0-\xa045.000 € Bruto/año', 'salesforce']
# Todos los textos de detales: ['Comercial\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tConsultor', 'Imprescindible Residir: País Puesto', 'Idiomas: Alemán (Excelente)', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tLicenciado', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEspecialista', 'Incentivos: Uncapped Commission', 'CVs inscritos en el proceso:  6']
# ----------------------------------------
# Nombre empresa : DAC.digital
# Título: UrgenteData Engineer with Snowflake
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Big Data']
# Time Stamp: 2025-02-19 10:38:29
# Tecnologías: ['snowflake', 'git', 'agile', 'data management', 'scrum', 'kanban', 'dbt']
# Todos los textos de los datos principales: ['100% En remoto', 'Not Required', 'Big Data', 'Jornada completa', '3-5 años', 'Freelance/Autónomo', '2.700 €\xa0-\xa06.000 € Bruto/mes', 'snowflakegitagiledata management']
# Todos los textos de detales: ['Big Data', 'Imprescindible Residir: Not Required', 'Idiomas: Inglés (Alto)', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tSin estudios', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEspecialista', 'CVs inscritos en el proceso:  27']
# ----------------------------------------
# Nombre empresa : Iron Mountain
# Título: UrgenteAccount Executive with Norwegian
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Comercial', 'Consultor']
# Time Stamp: 2025-02-19 10:38:30
# Tecnologías: ['git', 'marketing', 'net', 'data', 'salesforce', 'lan', 'crm', 'doors']
# Todos los textos de los datos principales: ['Llinars del Vallès -Barcelona(Híbrido)', 'País Puesto', 'Comercial', 'Jornada completa', '1 año', 'Indefinido', '39.000 €\xa0-\xa045.000 € Bruto/año', 'gitmarketingnetdata']
# Todos los textos de detales: ['Comercial\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tConsultor', 'Imprescindible Residir: País Puesto', 'Idiomas: Noruego (Excelente)', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tLicenciado', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEspecialista', 'Número de puestos: 2', 'Incentivos: Uncapped Commission', 'CVs inscritos en el proceso:  5']
# ----------------------------------------
# Nombre empresa : TELUS International
# Título: UrgenteOnline Data Analyst Spanish (ES)
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Analista']
# Time Stamp: 2025-02-19 10:38:30
# Tecnologías: ['Java']
# Todos los textos de los datos principales: ['100% En remoto', 'España', 'Analista', 'Por horas', 'Sin Experiencia', 'Freelance/Autónomo', 'Java']
# Todos los textos de detales: ['Analista', 'Imprescindible Residir: España', 'Idiomas: Inglés (Excelente)\t\t\t\t\t\t\t\t\t\t| \r\n\t\t\t\t\t\t\t\t\t\tEspañol (Excelente)', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tE.S.O. (Educación Secundaria Obligatoria)', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tPrácticas / Beca', 'Número de puestos: 50', 'CVs inscritos en el proceso:  50']
# ----------------------------------------
# Nombre empresa : Incoming Domain
# Título: Analista Pro. COBOL CICS DB2 JCL
# Fecha: 19/02/2025Nueva
# Habilidades: ['Analista', 'Analista Programador', 'Tester']
# Time Stamp: 2025-02-19 10:38:31
# Tecnologías: ['cobol', 'cics', 'db2', 'jcl']
# Todos los textos de los datos principales: ['Madrid- España', 'Alicante, Barcelona, Valencia y Zaragoza', 'Analista', 'Jornada completa', '3-5 años', 'Indefinido', '21.000 €\xa0-\xa030.000 € Bruto/año', 'cobolcicsdb2jcl']
# Todos los textos de detales: ['Analista\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tAnalista Programador\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tTester', 'Idiomas: Inglés (Alto)', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tDiplomado', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'Número de puestos: 6', 'CVs inscritos en el proceso:  0']
# ----------------------------------------
# Nombre empresa : NPR Spain
# Título: Service Manager Data & Analytics
# Fecha: 19/02/2025Nueva
# Habilidades: ['Big Data']
# Time Stamp: 2025-02-19 10:38:31
# Tecnologías: ['Agile', 'Azure', 'AWS', 'GCP', 'IBM']
# Todos los textos de los datos principales: ['Barcelona(Híbrido)', 'Provincia Puesto', 'Big Data', 'Jornada completa', '3 años', 'Indefinido', 'AgileAzureAWSGCP']
# Todos los textos de detales: ['Big Data', 'Imprescindible Residir: Provincia Puesto', 'Idiomas: Catalán (Alto)', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tGrado Medio', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  1']
# ----------------------------------------
# Nombre empresa : Digital Talent Agency
# Título: Desarrolladores/as Senior JAVA
# Fecha: 19/02/2025Nueva
# Habilidades: ['Programador']
# Time Stamp: 2025-02-19 10:38:32
# Tecnologías: ['java', 'sql', 'linux', 'oracle', 'git', 'agile', 'ci/cd', 'sql server']
# Todos los textos de los datos principales: ['100% En remoto', 'País Puesto', 'Programador', 'Jornada completa', '3-5 años', 'Indefinido', '36.000 €\xa0-\xa045.000 € Bruto/año', 'javasqllinuxoracle']
# Todos los textos de detales: ['Programador', 'Imprescindible Residir: País Puesto', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tFP2/Grado Superior', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEspecialista', 'Número de puestos: 4', 'CVs inscritos en el proceso:  1']
# ----------------------------------------
# Nombre empresa : Grupo Sermicro
# Título: Técnico/a micro con inglés
# Fecha: 19/02/2025Nueva
# Habilidades: ['Soporte Técnico']
# Time Stamp: 2025-02-19 10:38:32
# Tecnologías: ['soporte', 'ticketing']
# Todos los textos de los datos principales: ['villamayor -Salamanca(Presencial)', 'Provincia Puesto', 'Soporte Técnico', 'Jornada completa', '1 año', 'A determinar', 'soporteticketing']
# Todos los textos de detales: ['Soporte Técnico', 'Imprescindible Residir: Provincia Puesto', 'Idiomas: Inglés (Alto)', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tGrado Medio', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  0']
# ----------------------------------------
# Nombre empresa : Amazon
# Título: Software Development Engineer
# Fecha: 19/02/2025Nueva
# Habilidades: ['Programador']
# Time Stamp: 2025-02-19 10:38:33
# Tecnologías: ['FireTV']
# Todos los textos de los datos principales: ['Madrid- España', 'Programador', 'Jornada completa', '3 años', 'Indefinido', 'FireTV']
# Todos los textos de detales: ['Programador', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  0']
# ----------------------------------------
# Nombre empresa : Amazon
# Título: Software Development Engineer
# Fecha: 19/02/2025Nueva
# Habilidades: ['Inteligencia Artificial/Machine Learning', 'Programador']
# Time Stamp: 2025-02-19 10:38:33
# Tecnologías: ['C', 'C++', 'Python']
# Todos los textos de los datos principales: ['Madrid- España', 'Inteligencia Artificial/Machine Learning', 'Jornada completa', '3 años', 'Indefinido', 'CC++Python']
# Todos los textos de detales: ['Inteligencia Artificial/Machine Learning\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tProgramador', 'Idiomas: Inglés (Alto)', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  1']
# ----------------------------------------
# Nombre empresa : Amazon
# Título: Technical Account Manager
# Fecha: 19/02/2025Nueva
# Habilidades: ['Soporte Técnico']
# Time Stamp: 2025-02-19 10:38:34
# Tecnologías: ['AWS']
# Todos los textos de los datos principales: ['Madrid- España', 'Soporte Técnico', 'Jornada completa', '3 años', 'Indefinido', 'AWS']
# Todos los textos de detales: ['Soporte Técnico', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  1']
# ----------------------------------------
# Nombre empresa : WEEWOO
# Título: Junior Project manager
# Fecha: 19/02/2025Nueva
# Habilidades: ['Jefe de Proyecto']
# Time Stamp: 2025-02-19 10:38:34
# Tecnologías: ['Project manager']
# Todos los textos de los datos principales: ['Madrid- España', 'Jefe de Proyecto', 'Jornada completa', '2 años', 'Indefinido', 'Project manager']
# Todos los textos de detales: ['Jefe de Proyecto', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  1']
# ----------------------------------------
# Nombre empresa : EPAM
# Título: Java Developer (relocation Cyprus)
# Fecha: 19/02/2025Nueva
# Habilidades: ['Inteligencia Artificial/Machine Learning', 'Programador']
# Time Stamp: 2025-02-19 10:38:35
# Tecnologías: ['java', 'R', 'SQL']
# Todos los textos de los datos principales: ['Chipre- Chipre', 'España', 'Inteligencia Artificial/Machine Learning', 'Jornada completa', '3 años', 'Indefinido', 'javaRSQL']
# Todos los textos de detales: ['Inteligencia Artificial/Machine Learning\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tProgramador', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'Info Otros Países: \r\n\t\t\t\t\t\t\t\t\tEspaña', 'CVs inscritos en el proceso:  0']
# ----------------------------------------
# Nombre empresa : GMV
# Título: Ingeniero/a preventa ciberseguridad
# Fecha: 19/02/2025Nueva
# Habilidades: ['Comercial']
# Time Stamp: 2025-02-19 10:38:35
# Tecnologías: ['ciberseguridad']
# Todos los textos de los datos principales: ['Madrid(Híbrido)', 'Comercial', 'Jornada completa', '3 años', 'Indefinido', 'ciberseguridad']
# Todos los textos de detales: ['Comercial', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  0']
# ----------------------------------------
# Nombre empresa : Aristocrat
# Título: Affiliate Program - Website Manager
# Fecha: 19/02/2025Nueva
# Habilidades: ['Marketing', 'Soporte Técnico']
# Time Stamp: 2025-02-19 10:38:36
# Tecnologías: ['WordPress', 'Google Analytics']
# Todos los textos de los datos principales: ['Sliema -Malta- Malta', 'España', 'Marketing', 'Jornada completa', '3 años', 'Indefinido', 'WordPressGoogle Analytics']
# Todos los textos de detales: ['Marketing\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tSoporte Técnico', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'Info Otros Países: \r\n\t\t\t\t\t\t\t\t\tEspaña', 'CVs inscritos en el proceso:  0']
# ----------------------------------------
# Nombre empresa : Aristocrat
# Título: Product Owner
# Fecha: 19/02/2025Nueva
# Habilidades: ['Responsable de Producto']
# Time Stamp: 2025-02-19 10:38:37
# Tecnologías: ['Product Owner']
# Todos los textos de los datos principales: ['Warsaw -Polonia- Polonia', 'España', 'Responsable de Producto', 'Jornada completa', '3 años', 'Indefinido', 'Product Owner']
# Todos los textos de detales: ['Responsable de Producto', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'Info Otros Países: \r\n\t\t\t\t\t\t\t\t\tEspaña', 'CVs inscritos en el proceso:  0']
# ----------------------------------------
# Nombre empresa : CAS TRAINING
# Título: Senior Data Analyst - Spark Phyton
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Analista', 'Big Data']
# Time Stamp: 2025-02-19 10:38:37
# Tecnologías: ['python', 'sql', 'aws', 'data', 'cloud', 'etl', 'spark', 'postgresql']
# Todos los textos de los datos principales: ['100% En remoto', 'Analista', 'Jornada completa', '2 años', 'Indefinido', '39.000 €\xa0-\xa042.000 € Bruto/año', 'pythonsqlawsdata']
# Todos los textos de detales: ['Analista\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tBig Data', 'Idiomas: Inglés (Alto)', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tOtros títulos, certificaciones y carnets', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  5']
# ----------------------------------------
# Nombre empresa : Arelance
# Título: Programador Java
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Desarrollador Web', 'Programador']
# Time Stamp: 2025-02-19 10:38:38
# Tecnologías: ['java', 'sql', 'angular', 'spring', 'oracle', 'api rest']
# Todos los textos de los datos principales: ['Madrid(Híbrido)', 'España', 'Ávila, Guadalajara y Toledo', 'Desarrollador Web', 'Jornada completa', '2 años', 'Indefinido', '24.000 €\xa0-\xa030.000 € Bruto/año', 'javasqlangularspring']
# Todos los textos de detales: ['Desarrollador Web\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tProgramador', 'Imprescindible Residir: España', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tGrado Medio', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  7']
# ----------------------------------------
# Nombre empresa : CAS TRAINING
# Título: Analista Programador/a Cobol
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Analista Programador']
# Time Stamp: 2025-02-19 10:38:39
# Tecnologías: ['cobol', 'jcl']
# Todos los textos de los datos principales: ['Toda España -SalamancaEspaña', 'Analista Programador', 'Jornada completa', 'Más de 5 años', 'Indefinido', '24.000 €\xa0-\xa027.000 € Bruto/año', 'coboljcl']
# Todos los textos de detales: ['Analista Programador', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tFP2/Grado Superior', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEspecialista', 'CVs inscritos en el proceso:  7']
# ----------------------------------------
# Nombre empresa : Tuyú Technology
# Título: BECA Técnico/a de selección IT
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Reclutador']
# Time Stamp: 2025-02-19 10:38:39
# Tecnologías: ['rrhh', 'personio']
# Todos los textos de los datos principales: ['Madrid(Híbrido)', 'Provincia Puesto', 'Reclutador', 'Jornada completa', 'Sin Experiencia', 'Prácticas', '600 €\xa0-\xa0860 € Bruto/mes', 'rrhhpersonio']
# Todos los textos de detales: ['Reclutador', 'Imprescindible Residir: Provincia Puesto', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tGrado EEES (Bolonia)', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tPrácticas / Beca', 'CVs inscritos en el proceso:  2']
# ----------------------------------------
# Nombre empresa : Serem
# Título: Técnico/a soporte
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Soporte Técnico', 'Técnico de Sistemas', 'Técnico Hardware']
# Time Stamp: 2025-02-19 10:38:40
# Tecnologías: ['windows', 'soporte', 'hardware']
# Todos los textos de los datos principales: ['Vitoria -Álava(Presencial)', 'Provincia Puesto', 'Soporte Técnico', 'Jornada completa', '2 años', 'Indefinido', 'windowssoportehardware']
# Todos los textos de detales: ['Soporte Técnico\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tTécnico de Sistemas\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tTécnico Hardware', 'Imprescindible Residir: Provincia Puesto', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tFP2/Grado Superior', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  9']
# ----------------------------------------
# Nombre empresa : CAS TRAINING
# Título: QA Manual
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Tester']
# Time Stamp: 2025-02-19 10:38:40
# Tecnologías: ['team foundation server', 'visual studio', 'SQL server']
# Todos los textos de los datos principales: ['Madrid(Híbrido)', 'Provincia Puesto', 'Tester', 'Jornada completa', '3 años', 'Indefinido', '21.000 €\xa0-\xa024.000 € Bruto/año', 'team foundation servervisual studioSQL server']
# Todos los textos de detales: ['Tester', 'Imprescindible Residir: Provincia Puesto', 'Idiomas: Inglés (Medio)', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tOtros títulos, certificaciones y carnets', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  8']
# ----------------------------------------
# Nombre empresa : Arelance
# Título: Desarrollador/a Inteligencia Artificial
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Inteligencia Artificial/Machine Learning', 'Programador']
# Time Stamp: 2025-02-19 10:38:41
# Tecnologías: ['python', 'langchain', 'RAG', 'azure', 'aws', 'inteligencia artificial', 'ai', 'pytorch', 'tensorflow', 'LLM']
# Todos los textos de los datos principales: ['Madrid(Híbrido)', 'Ávila, Guadalajara, Segovia y Toledo', 'Inteligencia Artificial/Machine Learning', 'Jornada completa', '2 años', 'Indefinido', '27.000 €\xa0-\xa039.000 € Bruto/año', 'pythonlangchainRAGazure']
# Todos los textos de detales: ['Inteligencia Artificial/Machine Learning\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tProgramador', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tGrado Medio', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  2']
# ----------------------------------------
# Nombre empresa : PSS
# Título: Coordinador/a IT (Windows, SCCM)
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Administrador']
# Time Stamp: 2025-02-19 10:38:41
# Tecnologías: ['windows', 'SCCM', 'office 365']
# Todos los textos de los datos principales: ['Barcelona(Presencial)', 'Administrador', 'Jornada completa', '3 años', 'Indefinido', 'windowsSCCMoffice 365']
# Todos los textos de detales: ['Administrador', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tE.S.O. (Educación Secundaria Obligatoria)', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  20']
# ----------------------------------------
# Nombre empresa : PSS
# Título: Tecnico/a informatico/a  24*7
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Helpdesk', 'Soporte Técnico']
# Time Stamp: 2025-02-19 10:38:42
# Tecnologías: ['linux', 'unix', 'ticketing', 'control m']
# Todos los textos de los datos principales: ['Barcelona(Presencial)', 'Helpdesk', 'Jornada completa', 'Menos de un año', 'Indefinido', 'linuxunixticketingcontrol m']
# Todos los textos de detales: ['Helpdesk\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tSoporte Técnico', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tE.S.O. (Educación Secundaria Obligatoria)', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  22']
# ----------------------------------------
# Nombre empresa : Grupo Sermicro
# Título: Development Engineer
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Desarrollador Móvil', 'Desarrollador Web', 'Programador']
# Time Stamp: 2025-02-19 10:38:42
# Tecnologías: ['PHP', 'Android', 'iOS']
# Todos los textos de los datos principales: ['Burjassot -Valencia(Presencial)', 'Albacete, Alicante, Castellón y Teruel', 'Desarrollador Móvil', 'Jornada completa', '1 año', 'Indefinido', 'PHPAndroidiOS']
# Todos los textos de detales: ['Desarrollador Móvil\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tDesarrollador Web\t\t\t\t\t\t\t\t\t\t\n\r\n\t\t\t\t\t\t\t\t\t\t\tProgramador', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tIngeniero Técnico', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  211']
# ----------------------------------------
# Nombre empresa : Second Window
# Título: Programador Java (C1) AWS
# Fecha: 19/02/2025Actualizada
# Habilidades: ['Programador']
# Time Stamp: 2025-02-19 10:38:43
# Tecnologías: ['Java', 'Aws', 'TDD', 'BDD', 'CI/CD']
# Todos los textos de los datos principales: ['100% En remoto', 'Programador', 'Jornada completa', '3 años', 'Indefinido', 'JavaAwsTDDBDD']
# Todos los textos de detales: ['Programador', 'Idiomas: Inglés (Alto)', 'Formación Mínima: \r\n\t\t\t\t\t\t\t\t\tGrado Medio', 'Nivel Profesional: \r\n\t\t\t\t\t\t\t\t\tEmpleado', 'CVs inscritos en el proceso:  23']
# ----------------------------------------

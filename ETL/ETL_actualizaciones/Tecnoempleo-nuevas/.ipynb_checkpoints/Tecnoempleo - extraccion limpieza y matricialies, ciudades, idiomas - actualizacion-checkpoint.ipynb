# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
import time
import pickle
import numpy as np
import re
import ast
import toml
import mysql.connector
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/home/bosser/anaconda3/lib/python3.12/runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/bosser/anaconda3/lib/python3.12/runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/bosser/anaconda3/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/bosser/anaconda3/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/bosser/anaconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_8239/3576390727.py", line 2, in <module>
#     import pandas as pd
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/pandas/__init__.py", line 26, in <module>
#     from pandas.compat import (
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/pandas/compat/__init__.py", line 27, in <module>
#     from pandas.compat.pyarrow import (
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/pandas/compat/pyarrow.py", line 8, in <module>
#     import pyarrow as pa
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/home/bosser/anaconda3/lib/python3.12/runpy.py", line 198, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/bosser/anaconda3/lib/python3.12/runpy.py", line 88, in _run_code
#     exec(code, run_globals)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/bosser/anaconda3/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/bosser/anaconda3/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/bosser/anaconda3/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_8239/3576390727.py", line 2, in <module>
#     import pandas as pd
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/pandas/core/dtypes/dtypes.py", line 24, in <module>
#     from pandas._libs import (
#   File "/home/bosser/anaconda3/lib/python3.12/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.

# %%
config = toml.load("../.streamlit/secrets.toml")
db_config = config["database"]

db = mysql.connector.connect(host=db_config["host"],
                             user=db_config["user"],
                             password=db_config["password"],
                             database=db_config["database"]) 

cursor = db.cursor()

query_ultimo_id = """
SELECT id_oferta 
FROM ofertas 
WHERE id_oferta LIKE "id_tec_%" 
ORDER BY CAST(SUBSTRING_INDEX(id_oferta, "_", -1) AS UNSIGNED) DESC 
LIMIT 1;
"""
cursor.execute(query_ultimo_id)
ultimo_id_tec = cursor.fetchone()

query_urls = """
SELECT url 
FROM ofertas 
WHERE url LIKE "https://www.tecnoempleo.com%";
"""
cursor.execute(query_urls)
urls_existent = [url[0] for url in cursor.fetchall()]

# Consulta para obtener los datos de la tabla idiomas
query_idiomas = """
SELECT id_oferta, idioma, nivel
FROM idiomas;
"""
cursor.execute(query_idiomas)
idiomas_data = cursor.fetchall()
df_idiomas_original = pd.DataFrame(idiomas_data, columns=["id_oferta", "idioma", "nivel"])

cursor.close()
db.close()

# %%
def extraer_urls(urls_existent, num_paginas=None):

    base_url = "https://www.tecnoempleo.com/ofertas-trabajo/?pagina={}"
    nuevas_urls = [] 
    nombres_empresas = [] 
    ciudades = []
    pagina = 1

    while True:
        url = base_url.format(pagina)
        response = requests.get(url)

        if response.status_code != 200:
            print(f"Error al acceder a la página {pagina}")
            break

        soup = BeautifulSoup(response.text, "html.parser")
        enlaces = soup.find_all("a", class_="font-weight-bold text-cyan-700")
        urls = [enlace.get("href") for enlace in enlaces if enlace.get("href")]
        if not urls:
            print(f"No se encontraron más ofertas en la página {pagina}. Finalizando.")
            break
        for url in urls:
            if url not in urls_existent:  ##Añadimos solamente las urls que no están en la base de datos.
                nuevas_urls.append(url)

            # Extraemos los nombres de las empresas
            
            nombre_empresas = soup.find_all("a", class_="text-primary link-muted")
            for empresa in nombre_empresas:
                nombres_empresas.append(empresa.text.strip())
            for div in soup.find_all("div", class_="col-12 col-lg-3 text-gray-700 pt-2 text-right hidden-md-down"):
                if div.b:
                    ciudades.append(div.b.text.strip())
                else:
                    ciudades.append("No especificado")
                    
        # Calculamos el número total de páginas para asegurarnos de que las recorra todas:
        if num_paginas is None:
            total_ofertas = int(soup.find("h1").text.split()[0].replace(".", ""))
            total_paginas = (total_ofertas // 30) + (1 if total_ofertas % 30 != 0 else 0)
            if pagina >= total_paginas:
                break
        elif pagina >= num_paginas:
            break

        pagina +=1        

        if not urls:
            print(f"No se encontraron más ofertas en la página {pagina}. Finalizando.")
            break


    return nuevas_urls, nombres_empresas, ciudades

# Hacemos una función que recorre los urls para extraer los datos:
def extraer_datos_de_urls(nuevas_urls, nombres_empresas, ciudades):
    todas_las_ofertas = []
    todas_las_tecnologias = set()

    # Creamos un bucle que recorra las urls:
    for idx, link in enumerate(nuevas_urls):
        response_link = requests.get(link)
        if response_link.status_code != 200:
            print(f"Error al acceder a {link}")
            continue

        soup_link = BeautifulSoup(response_link.text, "html.parser")

        # Sacamos título, fecha, habilidades y añadimos el timestamp para que se indique la fecha en la que se han solicitado los datos. 
        titulo = soup_link.find("h1").get_text(strip=True) if soup_link.find("h1") else "Sin título"
        fecha = soup_link.find("span", class_="ml-4").get_text(strip=True) if soup_link.find("span", class_="ml-4") else "Sin fecha"
        habilidades = [x.text.strip() for x in soup_link.find_all("div", class_="d-flex py-2")[1].find_all("a")]
        timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

        # Tecnologías. En el caso de tecnologías, limpiamos ya la información que sacamos para que nos muestre solola tecnología 
        # sin el texto que no es necesario: "Ofertas de Empleo de":
        div = soup_link.find("div", class_="pl--12 pr--12")
        tecnologias = [a["title"].replace("Ofertas de Empleo de ", "").lower() for a in div.find_all("a") if div and a.has_attr("title")]
        todas_las_tecnologias.update(tecnologias)

        # Extraemos todos los datos principales
        todos_textos_enunciados = [span.get_text(strip=True) for span in soup_link.find_all("span", class_="d-inline-block px-2")]
        todos_textos = [span.get_text(strip=True) for span in soup_link.find_all("span", class_="float-end")]
        diccionario_principales = dict(zip(todos_textos_enunciados, todos_textos))

        # Extraemos otros detalles de la oferta
        todos_detalles = soup_link.find_all("p", class_="m-0")
        todos_textos_detalles = [x.text.strip() for x in todos_detalles if len(x["class"]) == 1][1:]
        diccionario_detalles = {}
        for item in todos_textos_detalles:
            if ":" in item:
                clave, valor = item.split(":", 1)
                diccionario_detalles[clave.strip()] = valor.strip()
            else:
                diccionario_detalles[item.strip()] = None

        # Creamos el diccionario para añadir toda la información
        oferta = {
            "Título": titulo,
            "URL": link,
            "Tecnologías": tecnologias,
            "Time Stamp": timestamp,
            "Fecha publicacion": fecha,
            "Habilidades": habilidades,
            "Nombre de empresa": nombres_empresas[idx] if idx < len(nombres_empresas) else "No encontrado",
            "Ciudad": ciudades[idx] if idx < len(ciudades) else "No especificado",  # # Nos aseguramos de que los nombres de empresas y 
            #las ciudades se corresponden con los urls sacados
        }

        # Creamos un bucle para asegurarnos de que añadimos todos los datos y, en el caso de que no haya datos, que se añadan también. 
        for clave, valor in diccionario_principales.items():
            oferta[clave] = valor if valor else "No especificado"

        for clave, valor in diccionario_detalles.items():
            oferta[clave] = valor if valor else "No especificado"

        todas_las_ofertas.append(oferta)
        print(f"Procesada oferta: {titulo}")
        print(len(todas_las_ofertas))

    # Creamos el DF
    df_ofertas = pd.DataFrame(todas_las_ofertas)

    # Creamos columnas binarias para cada tecnología. Esto nos facilita hacer un DF para más adelante relacionarlo con el DF principal. 
    for tecnologia in todas_las_tecnologias:
        df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
    df_ofertas.drop(columns=["Tecnologías"], inplace=True)

    return df_ofertas

# Llamamos a las funciones
nuevas_urls, nombres_empresas, ciudades = extraer_urls(urls_existent)
df_ofertas = extraer_datos_de_urls(nuevas_urls, nombres_empresas, ciudades)
df_ofertas.to_pickle("ofertas_nuevas_tecnoempleo.pkl") ###########PATH SALIDA
# Out:
# Procesada oferta: UrgenteTécnico Helpdesk
# 1
# Procesada oferta: UrgenteDesarrollador C# .Net Core
# 2
# Procesada oferta: C++ Tech Lead- I+D
# 3
# Procesada oferta: Desarrollador C ++
# 4
# Procesada oferta: Analista Pro. COBOL CICS DB2 JCL
# 5
# Procesada oferta: Desarrollador/a Java
# 6
# Procesada oferta: Administrador/a Storage L3 - Inglés
# 7
# Procesada oferta: DevOps Engineer
# 8
# Procesada oferta: Desarrollador/a RPA UiPath
# 9
# Procesada oferta: Appian Developer
# 10
# Procesada oferta: PL/SQL Developer
# 11
# Procesada oferta: Gerente Sector Público
# 12
# Procesada oferta: Ingeniero/a Infraestructura Cloud
# 13
# Procesada oferta: Consultant DevOps - Terraform, Ansible
# 14
# Procesada oferta: DevOps Analyst Terraform, Ansible, AWX
# 15
# Procesada oferta: Consultor Senior SAP SD
# 16
# Procesada oferta: Full Stack Developer
# 17
# Procesada oferta: Consultor Senior SAP FI
# 18
# Procesada oferta: Software Development Engineer
# 19
# Procesada oferta: Database Administrator (DBA)
# 20
# Procesada oferta: Software Development Manager
# 21
# Procesada oferta: Senior Full Stack Engineer
# 22
# Procesada oferta: Senior Software Engineer (Fullstack)
# 23
# Procesada oferta: Solution Architect
# 24
# Procesada oferta: Network Project Lead
# 25
# Procesada oferta: Desarrollador Senior Data Integration
# 26
# Procesada oferta: Third Party Risk IT & Cybersecurity Auditor
# 27
# Procesada oferta: Senior Business Warehouse Developer
# 28
# Procesada oferta: Cloud & Data Solution Analyst
# 29
# Procesada oferta: Senior Staff Software Engineer
# 30
# Procesada oferta: Senior Software Engineer
# 31
# Procesada oferta: Software Developer
# 32
# Procesada oferta: Cloud Infrastructure Engineer
# 33
# Procesada oferta: Third Party Risk IT & Cybersecurity
# 34
# Procesada oferta: Staff Software Engineer
# 35
# Procesada oferta: Java+testing Senior
# 36
# Procesada oferta: Arquitecto de Soluciones DevOps
# 37
# Procesada oferta: Cyber Threat Detection and Prevention
# 38
# Procesada oferta: Senior Data Engineer Python / AWS
# 39
# Procesada oferta: Genesys Cloud Developer
# 40
# Procesada oferta: Senior Salesforce Developer
# 41
# Procesada oferta: Senior Full-Stack Developer
# 42
# Procesada oferta: SecOps Cloud & Data Center Specialist
# 43
# Procesada oferta: IT Solution Architect
# 44
# Procesada oferta: Programador/a de PLC
# 45
# Procesada oferta: Desarrollador/a Full stack
# 46
# Procesada oferta: Senior iOS Engineer
# 47
# Procesada oferta: Real-Time Software Engineer
# 48
# Procesada oferta: Java Backend Software Engineer
# 49
# Procesada oferta: Analista de Fraude N3
# 50
# Procesada oferta: Desarrolladores Backend Java / Micros
# 51
# Procesada oferta: Consultor medios de pago
# 52
# Procesada oferta: Programador/a Fullstack Java React
# 53
# Procesada oferta: AP Java, Spring, JSF, EJB, JPA ¡Remoto!
# 54
# Procesada oferta: Desarrollador Full Stack (Java + VueJs)
# 55
# Procesada oferta: Consultor/a Transf. Digital-Salud
# 56
# Procesada oferta: Observability Engineer
# 57
# Procesada oferta: Administrador/a Teradata
# 58
# Procesada oferta: Programadores Angular
# 59
# Procesada oferta: Administrador SAP Basis (SAP BI / FIORI)
# 60
# Procesada oferta: Técnico de Redes z/OS VTAM-TCP/IP
# 61
# Procesada oferta: Programador/a Front Angular
# 62
# Procesada oferta: Administrado de Sistemas Senior z/OS
# 63
# Procesada oferta: Diseñador/a Java Microservicios
# 64
# Procesada oferta: Programador/a Cobol
# 65
# Procesada oferta: Desarrollador/a Java con Documentum
# 66
# Procesada oferta: Administrador/a de Sistemas GIS
# 67
# Procesada oferta: Analista Funcional
# 68
# Procesada oferta: Analista Funcional PEGA/Telecomunicacion
# 69
# Procesada oferta: Programador/a COBOL
# 70
# Procesada oferta: Consultor/a SAP Ariba Contracts
# 71
# Procesada oferta: Full Stack Developer Python, JavaScript
# 72
# Procesada oferta: Desarrollador/a Python
# 73
# Procesada oferta: Programador/a Apache Camel
# 74
# Procesada oferta: Desarrollador/a PL/SQL + Power BI
# 75
# Procesada oferta: Técnico/a seguridad de sistemas
# 76
# Procesada oferta: Desarrollador/a Senior NodeJS
# 77
# Procesada oferta: Medium Backend Developer
# 78
# Procesada oferta: Big Data Developer
# 79
# Procesada oferta: Gestor/a de Compras técnicas
# 80
# Procesada oferta: Analista Programador/a Java
# 81
# Procesada oferta: Técnico Calidad entrada electrónico
# 82
# Procesada oferta: Android Developer (Compose)
# 83
# Procesada oferta: Arquitecto Aplicaciones JAVA Cloud
# 84
# Procesada oferta: Desarrollador/a PHP
# 85
# Procesada oferta: Fullstack Programmer (Node.Js)
# 86
# Procesada oferta: Desarrollador Junior SQL/PLSQL
# 87
# Procesada oferta: QA Automation Lead/Manager
# 88
# Procesada oferta: Consultor/a Atlassian (B2)
# 89
# Procesada oferta: Arquitecto/a Sistemas TIBCO
# 90
# Procesada oferta: Técnico/a de soporte
# 91
# Procesada oferta: Ingeniero/a de Seguridad de Aplicaciones
# 92
# Procesada oferta: Full Stack Software Developer-Azure
# 93
# Procesada oferta: Senior Backend Developer
# 94
# Procesada oferta: Cybersecurity Analyst
# 95
# Procesada oferta: .NET Software Architect
# 96
# Procesada oferta: Desarrollador Fullstack Java
# 97
# Procesada oferta: Tecnico/a Genesys Cloud
# 98
# Procesada oferta: Senior Power BI Engineer. Inglés
# 99
# Procesada oferta: QA Junior
# 100
# Procesada oferta: Arquitecto/a de Soluciones
# 101
# Procesada oferta: Analista Programador Java/Angular
# 102
# Procesada oferta: Data Science IA Generativa
# 103
# Procesada oferta: Operador/a Sistemas 24x7
# 104
# Procesada oferta: Desarrollador/a .NET / REACT
# 105
# Procesada oferta: Riesgos Tecnológicos Analistas
# 106
# Procesada oferta: Arquitecto Cloud Azure
# 107
# Procesada oferta: Program Manager Infraestructuras
# 108
# Procesada oferta: Analista Programador Cobol
# 109
# Procesada oferta: Programador C/C++
# 110
# Procesada oferta: DevOps Engineer Kubernetes/AWS
# 111
# Procesada oferta: Analista Funcional Java/React
# 112
# Procesada oferta: Software Quality Assurance (SQA)
# 113
# Procesada oferta: Azure cloud Engineer
# 114
# Procesada oferta: Technical BI Developer
# 115
# Procesada oferta: QA tester
# 116
# Procesada oferta: Data Engineer/AI
# 117
# Procesada oferta: Programador/a Java Microservicios
# 118
# Procesada oferta: Microsoft Infrastructure Senior
# 119
# Procesada oferta: Técnico Especialista en Montaje SMD
# 120
# Procesada oferta: Fullstack Developer .Net + React
# 121
# Procesada oferta: IT Product Manager
# 122
# Procesada oferta: ITSM Automation and API
# 123
# Procesada oferta: Senior PL/SQL Developer
# 124
# Procesada oferta: Java Developer
# 125
# Procesada oferta: Junior DevSecOps Engineer
# 126
# Procesada oferta: Analista Reporting (seguimiento Issues)
# 127
# Procesada oferta: Desarrollador Senior Java Backend con Inglés
# 128
# Procesada oferta: Consultor/a SAP PM
# 129
# Procesada oferta: Programador/a IBM iSeries - RPG Free
# 130
# Procesada oferta: Programadores .NET
# 131
# Procesada oferta: Administrador Senior de IMS y/o CICS
# 132
# Procesada oferta: Ingeniero Administrador de Sistemas
# 133
# Procesada oferta: Data Engineer Scala
# 134
# Procesada oferta: Java software application Developer
# 135
# Procesada oferta: Técnico/a en Soporte Remedy
# 136
# Procesada oferta: Software Engineer
# 137
# Procesada oferta: API Engineer
# 138
# Procesada oferta: Consultor/a senior CRM Dynamics
# 139
# Procesada oferta: Desarrolladores Frontend
# 140
# Procesada oferta: Analista de Fraude Nivel 3
# 141
# Procesada oferta: Cyber - DevSecOps
# 142
# Procesada oferta: Backend Developer
# 143
# Procesada oferta: Open Source Senior Software Engineer
# 144
# Procesada oferta: Ruby on Rails Software Engineer
# 145
# Procesada oferta: Data Scientist
# 146
# Procesada oferta: Consultor Programador/a Java (HL7,)
# 147
# Procesada oferta: Analista PHP ¡Cliente Final!
# 148
# Procesada oferta: Machine Learning Ops
# 149
# Procesada oferta: Java Backend Developer
# 150
# Procesada oferta: Wintel Systems Administrator
# 151
# Procesada oferta: .NET Developer
# 152
# Procesada oferta: Power Platform Solutions Engineer
# 153
# Procesada oferta: Quality and Test Engineer
# 154
# Procesada oferta: Data Analyst/Engineer
# 155
# Procesada oferta: Application Architect
# 156
# Procesada oferta: Técnico IT - Generalista
# 157
# Procesada oferta: Técnico/a Informático/a Junior
# 158
# Procesada oferta: Desarrollador Web y SEO
# 159
# Procesada oferta: Técnico IT - Integración software
# 160
# Procesada oferta: Consultor/a Programador/a | Visual Basic
# 161
# Procesada oferta: Ingeniero de optimización
# 162
# Procesada oferta: Analista Técnico C# .NET SAP BusinessOne
# 163
# Procesada oferta: Applications Developer
# 164
# Procesada oferta: Technical IT/OT Manager
# 165
# Procesada oferta: Programador/a PLC/ROBOT
# 166
# Procesada oferta: Frontend Developer Angular Senior
# 167
# Procesada oferta: Expert Data Scientist
# 168
# Procesada oferta: Senior Full Stack (.NET/React)
# 169
# Procesada oferta: Backend Developer (.NET Core)
# 170
# Procesada oferta: Software Engineer, Early Career
# 171
# Procesada oferta: Cybersecurity Architect
# 172
# Procesada oferta: IT Business Analyst
# 173
# Procesada oferta: Senior Fullstack (React+Node) Developer
# 174
# Procesada oferta: Senior Software Development Engineer
# 175
# Procesada oferta: Desarrollador/a PYTHON
# 176
# Procesada oferta: Software Development Manager
# 177
# Procesada oferta: SAP Technology Consultant
# 178
# Procesada oferta: Industrial System Engineer
# 179
# Procesada oferta: Analista de Ciberseguridad
# 180
# Procesada oferta: Third Party Risk IT
# 181
# Procesada oferta: Junior Cloud Engineer
# 182
# Procesada oferta: Senior Software Developer
# 183
# Procesada oferta: Junior Java Microservices Developers
# 184
# Procesada oferta: IT Security Expert
# 185
# Procesada oferta: ORACLE con APEX
# 186
# Procesada oferta: Ingeniero/a de Ciberseguridad
# 187
# Procesada oferta: React Frontend Developer
# 188
# Procesada oferta: Solution Architect - Core Master Data
# 189
# Procesada oferta: Senior Software Engineer
# 190
# Procesada oferta: Software Architect - Subscription
# 191
# Procesada oferta: HelpDesk (Remoto)
# 192
# Procesada oferta: Desarrollador Java
# 193
# Procesada oferta: Data Engineer - Big Data
# 194
# Procesada oferta: Full-stack SW developer
# 195
# Procesada oferta: Third Party Risk IT & Cybersecurity
# 196
# Procesada oferta: Software Development Engineer
# 197
# Procesada oferta: Senior Data Engineer
# 198
# Procesada oferta: Technical/Application Support
# 199
# Procesada oferta: Senior Desarrolador PHP
# 200
# Procesada oferta: Junior Project Manager
# 201
# Procesada oferta: Senior Software Development
# 202
# Procesada oferta: Cloud Security Engineer
# 203
# Procesada oferta: Intern Software Engineer
# 204
# Procesada oferta: Desarrollador Java
# 205
# Procesada oferta: Manager Software Engineering
# 206
# Procesada oferta: Senior Full-Stack Developer (Risk Team)
# 207
# Procesada oferta: Software Engineer
# 208
# Procesada oferta: Android Engineer
# 209
# Procesada oferta: IS/IT Analyst SAP S/4 Group Reporting
# 210
# Procesada oferta: IT Project Manager
# 211
# Procesada oferta: Software Development Engineer
# 212
# Procesada oferta: Software Development Manager
# 213
# Procesada oferta: Cloud Engineer Expert - Azure
# 214
# Procesada oferta: Lead Data Analyst
# 215
# Procesada oferta: Nespresso - Data Analyst
# 216
# Procesada oferta: SAP Advanced Business
# 217
# Procesada oferta: .Net Developer
# 218
# Procesada oferta: Junior Javascript Programmer Analyst
# 219
# Procesada oferta: Programador/a PLC Junior
# 220
# Procesada oferta: UX/UI Designer
# 221
# Procesada oferta: Senior Java Software Developer
# 222
# Procesada oferta: IT Regional Product Owner
# 223
# Procesada oferta: Python Developer
# 224
# Procesada oferta: Marketing Digital & Data Analytics
# 225
# Procesada oferta: Técnico Informático Policompetencial
# 226
# Procesada oferta: Administrador/a Nutanix
# 227
# Procesada oferta: Técnico/a microinformático/a
# 228
# Procesada oferta: Analista Programador/a Java SpringBoot
# 229
# Procesada oferta: Senior Full Stack Developer
# 230
# Procesada oferta: Analista Programador Full Stack
# 231
# Procesada oferta: Ingeniero/a JAVA con INGLES
# 232
# Procesada oferta: Desarrollador/a Senior Drupal (PHP)
# 233
# Procesada oferta: Administrador/a Sistemas UNIX LINUX
# 234
# Procesada oferta: Técnicos de Sistemas Linux Red Hat
# 235
# Procesada oferta: Analista Full Stack Senior
# 236
# Procesada oferta: QA Automatización
# 237
# Procesada oferta: Ingeniero de Digitalización
# 238
# Procesada oferta: Python Microservices Architect
# 239
# Procesada oferta: IT Project Manager
# 240
# Procesada oferta: Software Engineer
# 241
# Procesada oferta: Técnico Java
# 242
# Procesada oferta: Desarrollador Genesys Cloud
# 243
# Procesada oferta: Programador/a Fullstack Java/Angular
# 244
# Procesada oferta: Azure Solution Architect
# 245
# Procesada oferta: AI Engineer
# 246
# Procesada oferta: Java Lead/Architect
# 247
# Procesada oferta: Analista Programador/a Senior
# 248
# Procesada oferta: Security Architect
# 249
# Procesada oferta: Programador ASO/ APX
# 250
# Procesada oferta: Ruby on Rails Developer - Fluent Italia
# 251
# Procesada oferta: Consultor Técnico TIC
# 252
# Procesada oferta: BIG DATA Developer-Market Risk
# 253
# Procesada oferta: Senior Power Bi Developer
# 254
# Procesada oferta: Coordinador de Marketing
# 255
# Procesada oferta: Desarrollador/a WordPress
# 256
# Procesada oferta: AWS Senior Admin
# 257
# Procesada oferta: Data Engineer
# 258
# Procesada oferta: Senior oracle developer
# 259
# Procesada oferta: Software Team Lead
# 260
# Procesada oferta: Product Manager Junior
# 261
# Procesada oferta: AWS DevOps Engineer
# 262
# Procesada oferta: Programador Senior REACT/Angular
# 263
# Procesada oferta: Cloud Infrastructure Engineer
# 264
# Procesada oferta: Junior Java Developer
# 265
# Procesada oferta: Test QA Engineer
# 266
# Procesada oferta: Programador Cells
# 267
# Procesada oferta: Ingeniero/a de Procesos
# 268
# Procesada oferta: Desarrollador/a Senior Fullstack
# 269
# Procesada oferta: Consultor SAP
# 270
# Procesada oferta: Technical Project Manager
# 271
# Procesada oferta: Programador/a Frontend (REACT Angular Node)
# 272
# Procesada oferta: Scala Engineer
# 273
# Procesada oferta: TABLEAU+SQL+PYTHON SR. Developer
# 274
# Procesada oferta: Técnico/a OT
# 275
# Procesada oferta: Ingeniero/a de datos Spark/Scala
# 276
# Procesada oferta: Desarrollador VUE3
# 277
# Procesada oferta: Programador/a Senior
# 278
# Procesada oferta: Administrador/a Sistemas UNIX/LINUX, X86,Cisco
# 279
# Procesada oferta: Especialista Desarrollo SW (.NET, SharePoint)
# 280
# Procesada oferta: Project Manager
# 281
# Procesada oferta: SQL Server Developer
# 282
# Procesada oferta: Senior Production Support
# 283
# Procesada oferta: MLOps Machine Learning
# 284
# Procesada oferta: Programador Java + Apache Camel
# 285
# Procesada oferta: Ingeniero de datos junior Pyspark
# 286
# Procesada oferta: Encargado de Compras
# 287
# Procesada oferta: Project Manager Software con Inglés
# 288
# Procesada oferta: IT Assistant Manager
# 289
# Procesada oferta: Tecnico/a Contact Center Genesys Cloud CX
# 290
# Procesada oferta: Consultor Oracle APEX (Ingles C1)
# 291
# Procesada oferta: ACPM Developer - Procesos Backend
# 292
# Procesada oferta: Tech Project Manager
# 293
# Procesada oferta: BMS C++
# 294
# Procesada oferta: BackEnd Developer
# 295
# Procesada oferta: Spark / Scala Developer
# 296
# Procesada oferta: Técnico Migración BPel a Apache CAMEL
# 297
# Procesada oferta: Desarrollador/a Spark-Scala
# 298
# Procesada oferta: Backend Lead (Node JS)
# 299
# Procesada oferta: Analista programador en ASP.net
# 300
# Procesada oferta: Desarrollador Junior REACT Node
# 301
# Procesada oferta: Business Analyst
# 302
# Procesada oferta: API Design/Support/Analyst Engineer Jr.
# 303
# Procesada oferta: Técnico Soporte, Inglés B2
# 304
# Procesada oferta: Medium Back-End Developer
# 305
# Procesada oferta: Splunk Consultant
# 306
# Procesada oferta: Data Analyst
# 307
# Procesada oferta: Big Data Developer
# 308
# Procesada oferta: PostgreSQL Developer
# 309
# Procesada oferta: Técnico/a microinformática con Francés
# 310
# Procesada oferta: Consultor de Ciberseguridad
# 311
# Procesada oferta: Desarrollador C
# 312
# Procesada oferta: .NET Developer
# 313
# Procesada oferta: Técnico/a ciberseguridad
# 314
# Procesada oferta: Técnico ITIL & CMDB en remoto
# 315
# Procesada oferta: Técnico/a microinformático
# 316
# Procesada oferta: Desarrollador CA Clarity PPM (GEL, SQL)
# 317
# Procesada oferta: Operador/a de Servicios (turnos)
# 318
# Procesada oferta: Data Lake - Senior Developer
# 319
# Procesada oferta: DBA expert (Data Engineering)
# 320
# Procesada oferta: Desarrollador/a de SW en IA
# 321
# Procesada oferta: Arquitecto/a de Software Senior
# 322
# Procesada oferta: Desarrolladores Java/Linux Integración
# 323
# Procesada oferta: CRM Coordinator
# 324
# Procesada oferta: Product Marketing Team Lead
# 325
# Procesada oferta: Back End Developer
# 326
# Procesada oferta: Backend .Net Developer
# 327
# Procesada oferta: Senior Software Engineer
# 328
# Procesada oferta: Técnico Soporte Junior Medios de Pago
# 329
# Procesada oferta: Consultor/a SAP BW
# 330
# Procesada oferta: Arquitecto/a Java
# 331
# Procesada oferta: Técnico/a de Soporte Ingles
# 332
# Procesada oferta: Senior Technical Consultant
# 333
# Procesada oferta: QA Automation tester
# 334
# Procesada oferta: Microsoft Administrator
# 335
# Procesada oferta: Ingeniero de Verificación de Diseño
# 336
# Procesada oferta: Backend Engineer for Business Telemetry
# 337
# Procesada oferta: AI Quality Engineer
# 338
# Procesada oferta: Senior Frontend Developer
# 339
# Procesada oferta: Python Developer
# 340
# Procesada oferta: Oracle Lead
# 341
# Procesada oferta: AWS fin ops sme
# 342
# Procesada oferta: Tech Lead
# 343
# Procesada oferta: Marketplace Account Manager
# 344
# Procesada oferta: Trader
# 345
# Procesada oferta: Community Manager
# 346
# Procesada oferta: Responsable de producción
# 347
# Procesada oferta: Ingeniero/a de Diseño
# 348
# Procesada oferta: Desarrolladores control tráfico aéreo
# 349
# Procesada oferta: Desarrollador fullstack ReactJS/NET
# 350
# Procesada oferta: Client Contribution Analyst
# 351
# Procesada oferta: Software Engineer
# 352
# Procesada oferta: PySpark Developer
# 353
# Procesada oferta: POWER BI + POWER APPs developer
# 354
# Procesada oferta: Game Developer
# 355
# Procesada oferta: Lead Software Developer AWS
# 356
# Procesada oferta: Digital Content Specialist - agency
# 357
# Procesada oferta: Desarrollador/a .NET
# 358
# Procesada oferta: Administrador sistemas UNIX/LINUX
# 359
# Procesada oferta: Account Manager SAP
# 360
# Procesada oferta: Desarrollador/a iOS
# 361
# Procesada oferta: Grafana Admin
# 362
# Procesada oferta: Salesforce Technical Lead
# 363
# Procesada oferta: Tester Middleware
# 364
# Procesada oferta: Administrador/a Senior Storage Mainframe
# 365
# Procesada oferta: Senior Data Analyst
# 366
# Procesada oferta: Programador Junior GCP (vue+Python)
# 367
# Procesada oferta: Java Developer
# 368
# Procesada oferta: Senior Oracle Developer
# 369
# Procesada oferta: Desarrollador Android
# 370
# Procesada oferta: C++ Software Engineer
# 371
# Procesada oferta: AI Engineer
# 372
# Procesada oferta: Junior Project Manager
# 373
# Procesada oferta: Administrador/a Middleware
# 374
# Procesada oferta: IP Engineer
# 375
# Procesada oferta: Front End Lead ReactJS
# 376
# Procesada oferta: Programador Junior Angular REACT
# 377
# Procesada oferta: ServiceNow Tester
# 378
# Procesada oferta: Desarrollador Node remoto
# 379
# Procesada oferta: Java Developer
# 380
# Procesada oferta: Content Designer (UI/UX)
# 381
# Procesada oferta: OT System Engineer
# 382
# Procesada oferta: Data Engineer
# 383
# Procesada oferta: Técnico HelpDesk, Inglés B2
# 384
# Procesada oferta: Senior Production Support
# 385
# Procesada oferta: Programador Full Stack
# 386
# Procesada oferta: Software Development Manager
# 387
# Procesada oferta: Consultor SAP SD
# 388
# Procesada oferta: Front end
# 389
# Procesada oferta: Tester Level 2/Clarity Developer
# 390
# Procesada oferta: Game Developer
# 391
# Procesada oferta: IT Pre Sales Engineer
# 392
# Procesada oferta: SEO Specialist
# 393
# Procesada oferta: Business Operations
# 394
# Procesada oferta: Azure Cybersecurity Engineer
# 395
# Procesada oferta: M365 Security Engineer
# 396
# Procesada oferta: IT Project Manager
# 397
# Procesada oferta: Operational Security Engineering
# 398
# Procesada oferta: Test Engineer-TOSCA
# 399
# Procesada oferta: IT Project Manager
# 400
# Procesada oferta: OT Network
# 401
# Procesada oferta: Team Lead Software
# 402
# Procesada oferta: Senior Architect
# 403
# Procesada oferta: ETL Developer
# 404
# Procesada oferta: Desarrollador/a FullStack
# 405
# Procesada oferta: Senior Data Science Director
# 406
# Procesada oferta: Líder Técnico .NET CORE
# 407
# Procesada oferta: UX/UI Designer
# 408
# Procesada oferta: Dirección de Marketing
# 409
# Procesada oferta: Database Administrator SRE
# 410
# Procesada oferta: Java Developer
# 411
# Procesada oferta: Technical Lead Full stack
# 412
# Procesada oferta: Técnico Informático
# 413
# Procesada oferta: QA Automation (UFT)
# 414
# Procesada oferta: Tecnicos Junior de Soporte SAP MM
# 415
# Procesada oferta: Desarrollador/a de Software C++
# 416
# Procesada oferta: Ingeniero Machine Learning
# 417
# Procesada oferta: Administrador/a LINUX N3 - Cliente final
# 418
# Procesada oferta: Solution Architect - Arquitecto de soluciones
# 419
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# ...
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)
# /tmp/ipykernel_8239/2392750777.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas[tecnologia] = df_ofertas["Tecnologías"].apply(lambda x: 1 if tecnologia in x else 0)

# %%
extraccion = "ofertas_nuevas_tecnoempleo.pkl"

# %%
def limpieza_tecnoempleo_actualizacion(extraccion, ultimo_id_tec):

    ultimo_numero = int(ultimo_id_tec[0].split("_")[-1])  # Obtiene el número final del ID
    
    df_ofertas = pd.read_pickle(extraccion)
    
    # Generar nuevos IDs a partir del siguiente número
    df_ofertas["id"] = ["id_tec_" + str(i) for i in range(ultimo_numero + 1, ultimo_numero + 1 + len(df_ofertas))]
    
    # Reordenar la columna "id" al inicio
    columna_extraida_ = df_ofertas.pop("id")
    df_ofertas.insert(0, "id", columna_extraida_)
    
    
    #Generamos df matricial de tecnologías, lo pasamos a pickle y eliminamos las columnas
    df_tecnologias_matricial = df_ofertas[[df_ofertas.columns[0]] + list(df_ofertas.columns[25:])]
    lista_tecnologias = list(df_ofertas.columns[25:])
    df_ofertas.drop(columns=lista_tecnologias, inplace=True) 
    
    
    # Renombramos la columna con título vacío (columna con información de trabajo remoto o no):
    df_ofertas.rename(columns={"": "Teletrabajo"}, inplace=True)
    
    # De la información que nos quedamos en la columna de Teletrabajo, unificamos los valores por: 100% en remoto, híbrido y presencial.
    df_ofertas["Teletrabajo"] = df_ofertas["Teletrabajo"].apply(lambda x: "Remoto" if "Remoto" in x or "Teletrabajo" in x 
                                                                else "Híbrido" if "Híbrido" in x else "Presencial")
    
    # Verificamos los resultados
    df_ofertas["Teletrabajo"].unique()
    
    # Limpiamos la columna de Fecha de publicación, eliminando el texto que nos sobra y convirtiendo a datetime:
    df_ofertas["Fecha publicacion"] = df_ofertas["Fecha publicacion"].str.replace("Actualizada", "").str.replace("Nueva", "")
    df_ofertas["Fecha publicacion"] = pd.to_datetime(df_ofertas["Fecha publicacion"], format="%d/%m/%Y")
    
    # Quitamos los caracteres no deseados de la columna Idiomas y dividimos la columna en dos: una para el idioma y otra para el nivel.
    df_ofertas["Idiomas"] = df_ofertas["Idiomas"].fillna("")
    df_ofertas["Idiomas"] = df_ofertas["Idiomas"].str.replace(r"[\t\r\n|]", "", regex=True)
    
    # Extraemos todos los Idiomas y niveles
    def extraer_Idiomas_niveles(texto):
        if not texto.strip():  
            return np.nan, np.nan
        matches = re.findall(r"(\w+)\s*\((\w+)\)", texto)
        if not matches:
            return np.nan, np.nan 
        Idiomas = [match[0] for match in matches]
        niveles = [match[1] for match in matches]
    
        # Unimos los Idiomas y niveles en cadenas separadas por comas
        return ", ".join(Idiomas), ", ".join(niveles)
    
    
    df_ofertas[["Idiomas_limpios", "niveles_limpios"]] = df_ofertas["Idiomas"].apply(extraer_Idiomas_niveles).apply(pd.Series)
    
    
    df_ofertas["Idiomas_limpios"] = df_ofertas["Idiomas_limpios"].replace("", np.nan)
    df_ofertas["niveles_limpios"] = df_ofertas["niveles_limpios"].replace("", np.nan)
    
    
    df_ofertas.drop(columns=["Idiomas"], inplace=True)
    
    # Dataframe solo con id, idiomas y niveles limpios
    df_idiomas1 = df_ofertas[["id","Idiomas_limpios","niveles_limpios"]]
    
    # Por cada idioma y nivel, creamos un diccionario con el id, idioma y nivel y los añade a una lista
    dict_list = []
    for i, row in df_idiomas1.iterrows():
        if pd.notna(row["Idiomas_limpios"]) and pd.notna(row["niveles_limpios"]):
            idiomas = row["Idiomas_limpios"].split(", ")
            niveles = row["niveles_limpios"].split(", ")
            for idioma, nivel in zip(idiomas, niveles):
                dict_list.append({"id": row["id"], "idioma": idioma, "nivel": nivel})
        else:
            dict_list.append({"id": row["id"], "idioma": None, "nivel": None})
    
    df_ofertas.drop(columns = ["Idiomas_limpios", "niveles_limpios"], inplace = True)
    # Convertimos la lista de diccionarios a un dataframe
    df_idiomas = pd.DataFrame(dict_list)
    
    df_idiomas_original.rename(columns={"id_oferta": "id"}, inplace=True)
    
    df_idiomas_actualizado = pd.concat([df_idiomas, df_idiomas_original], ignore_index=True)
    
    
    # Limpiamos la columna de Salario y la unificamos a bruto por año.
    
    # Separamos las columnas para crear una con la unidad reflejada (mes, año, hora):
    split_data = df_ofertas["Salario"].str.split(" Bruto/", expand=True)
    df_ofertas["Rango"] = split_data[0]  
    df_ofertas["Unidad"] = split_data[1] 
    
    # Dividimos los valores para hacer dos columnas de mínimo y máximo:
    rango_split = df_ofertas["Rango"].str.split("-\xa0", expand=True)
    df_ofertas["Min"] = rango_split[0].str.replace("€", "").str.replace(".", "").str.strip().astype(float)
    df_ofertas["Max"] = rango_split[1].str.replace("€", "").str.replace(".", "").str.strip().astype(float)
    
    # Usamos where para cambiar la palabra mes por 12 y hora por 2080 (40h a la semana por 52 semanas):
    df_ofertas["Factor"] = np.where(
        df_ofertas["Unidad"] == "mes", 12,
        np.where(df_ofertas["Unidad"] == "hora", 2080, 1)
    )
    # Multiplicamos las columnas y dividimos por mil para una mejor visualización:
    df_ofertas["salario_desde"] = df_ofertas["Min"] * df_ofertas["Factor"] / 1000
    df_ofertas["salario_hasta"] = df_ofertas["Max"] * df_ofertas["Factor"] / 1000
    
    df_ofertas.drop(columns=["Rango", "Unidad", "Min", "Max", "Factor"], inplace=True)
    
    # Para la información de la columna de habilidades, creamos un nuevo DF:
    df_habilidades_matricial_tecnoempleo_actualizacion = df_ofertas[["id", "Habilidades"]].copy()
        
    # Creamos una lista con las habilidades sin duplicar:
    todas_habilidades = sum(df_habilidades_matricial_tecnoempleo_actualizacion["Habilidades"], [])
    habilidades_unicas = list(set(todas_habilidades))
    
    # Creamos columnas binarias para cada habilidad:
    for habilidad in habilidades_unicas:
        df_habilidades_matricial_tecnoempleo_actualizacion[habilidad] = df_habilidades_matricial_tecnoempleo_actualizacion["Habilidades"].apply(
            lambda x: 1 if habilidad in x else 0)
    
    df_habilidades_matricial_tecnoempleo_actualizacion.drop(columns=["Habilidades"], inplace=True)
    
    
    #Imprescindible residir, cambiamos los valores para unicficarlos:
    df_ofertas["Imprescindible Residir"] = df_ofertas["Imprescindible Residir"].replace(
        {"España": "País Puesto", "Spain": "País Puesto", "Country": "País Puesto", 
         "Not Required": "No requerido"})
    df_ofertas["Imprescindible Residir"]
    
    # Duplicamos filas por ID, para asociar todas las provincias relacionadas con ese ID y hacemos un nuevo DF:
    df_provincias = df_ofertas[["id", "Otras Provincias"]]
    
    df_provincias["Otras Provincias"] = df_provincias["Otras Provincias"].apply(lambda x: str(x).split(", ") if pd.notna(x) else [None])
    
    df_provincias = df_provincias.explode("Otras Provincias").reset_index(drop=True)
    
    
    df_ofertas.drop(columns=["Otras Provincias"], inplace=True)
    
    #Generamos los pickles
    df_ofertas.to_pickle("../Fusion_actualizacion/general_tecnoempleo_limpio.pkl")
    df_habilidades_matricial_tecnoempleo_actualizacion.to_pickle("../Fusion_actualizacion/habilidades_matricial_tecnoempleo_actualizacion.pkl")
    df_idiomas_actualizado.to_pickle("idiomas_actualizacion.pkl")###########PATH SALIDA
    df_tecnologias_matricial.to_pickle("../Fusion_actualizacion/tecnologias_matricial_tecnoempleo_actualizacion.pkl")
    df_provincias.to_pickle("../Fusion_actualizacion/provincias.pkl")###########PATH SALIDA

# %%
limpieza_tecnoempleo_actualizacion(extraccion, ultimo_id_tec)
# Out:
# /tmp/ipykernel_8239/489962405.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas["id"] = ["id_tec_" + str(i) for i in range(ultimo_numero + 1, ultimo_numero + 1 + len(df_ofertas))]
# /tmp/ipykernel_8239/489962405.py:12: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_ofertas.insert(0, "id", columna_extraida_)
# /tmp/ipykernel_8239/489962405.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_provincias["Otras Provincias"] = df_provincias["Otras Provincias"].apply(lambda x: str(x).split(", ") if pd.notna(x) else [None])
